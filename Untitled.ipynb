# %%
import sys
import numpy as np
import tensorflow as tf
from datetime import datetime

device_name="/gpu:0"

shape=(int(10000),int(10000))

with tf.device(device_name):
    random_matrix = tf.random_uniform(shape=shape, minval=0, maxval=1)
    dot_operation = tf.matmul(random_matrix, tf.transpose(random_matrix))
    sum_operation = tf.reduce_sum(dot_operation)

startTime = datetime.now()
with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as session:
        result = session.run(sum_operation)
        print(result)

print("\n" * 2)
print("Shape:", shape, "Device:", device_name)
print("Time taken:", datetime.now() - startTime)

print("\n" * 2)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#
# C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1116       # Ensure any changes to the graph are reflected in the runtime.
# -> 1117       self._extend_graph()
#    1118       with errors.raise_exception_on_not_ok_status() as status:
#
# C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\client\session.py in _extend_graph(self)
#    1165           tf_session.TF_ExtendGraph(
# -> 1166               self._session, graph_def.SerializeToString(), status)
#    1167         self._opened = True
#
# C:\Miniconda3\envs\carnd-term1\lib\contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\framework\errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InvalidArgumentError: Cannot assign a device for operation 'random_uniform/sub': Operation was explicitly assigned to /device:GPU:0 but available devices are [ /job:localhost/replica:0/task:0/cpu:0 ]. Make sure the device specification refers to a valid device.
# 	 [[Node: random_uniform/sub = Sub[T=DT_FLOAT, _device="/device:GPU:0"](random_uniform/max, random_uniform/min)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-1-4e363d2f9fe9> in <module>()
#      15 startTime = datetime.now()
#      16 with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as session:
# ---> 17         result = session.run(sum_operation)
#      18         print(result)
#      19
#
# C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1150         except KeyError:
#    1151           pass
# -> 1152       raise type(e)(node_def, op, message)
#    1153
#    1154   def _extend_graph(self):
#
# InvalidArgumentError: Cannot assign a device for operation 'random_uniform/sub': Operation was explicitly assigned to /device:GPU:0 but available devices are [ /job:localhost/replica:0/task:0/cpu:0 ]. Make sure the device specification refers to a valid device.
# 	 [[Node: random_uniform/sub = Sub[T=DT_FLOAT, _device="/device:GPU:0"](random_uniform/max, random_uniform/min)]]
#
# Caused by op 'random_uniform/sub', defined at:
#   File "C:\Miniconda3\envs\carnd-term1\lib\runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Miniconda3\envs\carnd-term1\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Miniconda3\envs\carnd-term1\lib\asyncio\base_events.py", line 345, in run_forever
#     self._run_once()
#   File "C:\Miniconda3\envs\carnd-term1\lib\asyncio\base_events.py", line 1312, in _run_once
#     handle._run()
#   File "C:\Miniconda3\envs\carnd-term1\lib\asyncio\events.py", line 125, in _run
#     self._callback(*self._args)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\tornado\platform\asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-4e363d2f9fe9>", line 11, in <module>
#     random_matrix = tf.random_uniform(shape=shape, minval=0, maxval=1)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\ops\random_ops.py", line 237, in random_uniform
#     return math_ops.add(rnd * (maxval - minval), minval, name=name)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\ops\math_ops.py", line 838, in binary_op_wrapper
#     return func(x, y, name=name)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\ops\gen_math_ops.py", line 2501, in _sub
#     result = _op_def_lib.apply_op("Sub", x=x, y=y, name=name)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\framework\ops.py", line 2506, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "C:\Miniconda3\envs\carnd-term1\lib\site-packages\tensorflow\python\framework\ops.py", line 1269, in __init__
#     self._traceback = _extract_stack()
#
# InvalidArgumentError (see above for traceback): Cannot assign a device for operation 'random_uniform/sub': Operation was explicitly assigned to /device:GPU:0 but available devices are [ /job:localhost/replica:0/task:0/cpu:0 ]. Make sure the device specification refers to a valid device.
# 	 [[Node: random_uniform/sub = Sub[T=DT_FLOAT, _device="/device:GPU:0"](random_uniform/max, random_uniform/min)]]
